# %%
import csv
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
url = 'https://www.monsterindia.com/srp/results?query=Data%20Scientist&locations=Delhi'

# %%
#Function to clean some text
def remove(string): 
    return string.replace(" ", "").replace("\n", " ")

# %%
#Function for extracting data from one search result
def extract_record(item):
    """extract and return result from a single result"""
    try:
        postition = item.h3.a.text
        comapny = item.span.a.text
        location = item.find('div',{'class':'col-xxs-12 col-sm-5 text-ellipsis'}).text.strip()
        experience = item.find('div',{'class':'exp col-xxs-12 col-sm-3 text-ellipsis'}).text.strip()
        salary = item.find('div',{'class':'package col-xxs-12 col-sm-4 text-ellipsis'}).text.strip()
        jd = item.find('p',{'class':'job-descrip'}).text.strip()
        skills = remove(item.find('p',{'class':'descrip-skills'}).text.strip())
        posted = item.find('span',{'class':'posted'}).text.strip()
    except AttributeError:
        return
    result = (postition,comapny,location,experience,salary,jd,skills,posted)
    return result

# %%
records=[]
driver = webdriver.Chrome()
driver.get(url)
soup = BeautifulSoup(driver.page_source,'html.parser')
results = soup.find_all('div',{"class":"card-panel apply-panel job-apply-card"})
for item in results:
    record = extract_record(item)
    records.append(record)
driver.close()

# %%
records
# Out:
# [('Data Analyst / Fresher /  Data Scientist / Graduate Fresher  - MNC - 7303778896 | 9560245147',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Ghaziabad',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:\n    \n    Call @ 7303778896 | 9560245147',
#   'Skills: Freshers , Graduates , GraduateFresher , DataEntry , DataAnalysis , Mis , MarketResearch , Word , MISAnalyst , MisExecutive , BackOffice , Backend , DataManagement , Excel , DataScience , OperationsExecutive',
#   'Posted: 5 days ago'),
#  ('Data Analyst / Fresher /  Data Scientist / Graduate Fresher  - MNC - 7303778896 | 9560245147',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Ghaziabad',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:\n  \n  Call @ 7303778896 | 9560245147',
#   'Skills: Freshers , Graduates , GraduateFresher , DataEntry , DataAnalysis , Mis , MarketResearch , Word , MISAnalyst , MisExecutive , BackOffice , Backend , DataManagement , Excel , DataScience , OperationsExecutive',
#   'Posted: 21 days ago'),
#  ('Data Analyst / Fresher /  Data Scientist / Graduate Fresher  - MNC - 7303778896 | 9560245147',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Gurgaon / Gurugram',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:\n   \n   Call @ 7303778896 | 9560245147',
#   'Skills: Freshers , Graduates , GraduateFresher , DataEntry , DataAnalysis , Mis , MarketResearch , Word , MISAnalyst , MisExecutive , BackOffice , Backend , DataManagement , Excel , DataScience , OperationsExecutive',
#   'Posted: 16 days ago'),
#  ('Data Analyst – Fresher – Data Scientist – Any Graduate - Fresher  6397800351 | 9717266846',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Noida',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:',
#   'Skills: DataAnalyst , MIreportdevelopment , DataScientist',
#   'Posted: 30+ days ago'),
#  ('Data Analyst – Fresher – Data Scientist – Graduate - Fresher  7303778896 | 9560245147 | 6397800351 ',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Gurgaon / Gurugram',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:\n  \n  Call @ 7303778896 | 9560245147 | 6397800351',
#   'Skills: Freshers , Graduates , GraduateFresher , DataEntry , DataAnalysis , Mis , MarketResearch , Word , MISAnalyst , MisExecutive , BackOffice , Backend , DataManagement , Excel , DataScience , OperationsExecutive',
#   'Posted: 30+ days ago'),
#  ('Data Analyst – Fresher – Data Scientist – Graduate - Fresher  7303778896 | 9560245147 | 6397800351 ',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Noida',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:\n \n Call @ 7303778896 | 9560245147 | 6397800351',
#   'Skills: Freshers , Graduates , GraduateFresher , DataEntry , DataAnalysis , Mis , MarketResearch , Word , MISAnalyst , MisExecutive , BackOffice , Backend , DataManagement , Excel , DataScience , OperationsExecutive',
#   'Posted: 30+ days ago'),
#  ('DATA ANALYST – FRESHER – DATA SCIENTIST – SAS – PYTHON – TABLEAU - Fresher / Exp',
#   'Structured Learning Assistance Consultants India Private Limited',
#   'Delhi, Noida',
#   '0-5 Years',
#   'Not Specified',
#   'Fresher Can Apply:',
#   'Skills: DataAnalyst , DataAnalysis , BusinessAnalytics , MarketResearch , fresheranalyst , DataAnalytics , ResearchAnalyst',
#   'Posted: 30+ days ago'),
#  ('Data Scientist',
#   'Talent Corner Hr Services Private Limited',
#   'Pune, Delhi NCR',
#   '3-6 Years',
#   'Not Specified',
#   'Job Description :\n\n\nJob Description\n\n\nHands-on knowledge of Python for building production-ready data products.\nStrong Statistical Analysis and Modeling skills.\nProven skills in Data Science, Data Mining, Machine Learning, covering the spectrum of su',
#   'Skills: DataScientist',
#   'Posted: 30+ days ago'),
#  ('Data Scientist - 11',
#   'Accenture',
#   'Delhi, Mumbai',
#   '0-3 Years',
#   'Not Specified',
#   'Job Description\n\nAbout Accenture:\nAccenture is a leading global professional services company, providing a broad range of services in strategy and consulting, interactive, technology and operations, with digital capabilities across all of these servi',
#   'Skills: Strategy',
#   'Posted: 30+ days ago'),
#  ('Data Scientist - 09',
#   'Accenture',
#   'Delhi, Mumbai',
#   '3-6 Years',
#   'Not Specified',
#   'Job Description\n\nAbout Accenture:\nAccenture is a leading global professional services company, providing a broad range of services in strategy and consulting, interactive, technology and operations, with digital capabilities across all of these servi',
#   'Skills: Strategy',
#   'Posted: 30+ days ago'),
#  ('Data Scientist - 11',
#   'Accenture',
#   'Delhi, Mumbai',
#   '0-3 Years',
#   'Not Specified',
#   'Job Description\n\nAbout Accenture:\nAccenture is a leading global professional services company, providing a broad range of services in strategy and consulting, interactive, technology and operations, with digital capabilities across all of these servi',
#   'Skills: Strategy',
#   'Posted: 30+ days ago'),
#  ('Data Scientist - Gurgaon || Experience 5 - 7 years',
#   'WNS Global Services Private Limited',
#   'Delhi, Delhi NCR',
#   'Not Specified',
#   '6,00,000-9,50,000 INR',
#   'Job Description\n\n\nExperience\nExperience of 5 to 7 years in working on deep learning techniques using Python\n\nKey Responsibilities\n\n  * Design, train and deliver machine learning solutions to a wide range of datasets: from small datasets to big data,',
#   'Skills: StatisticalModeling , DataScience , MachineLearning , DeepLearning , Python',
#   'Posted: a month ago'),
#  ('Assistant Manager - Data Scientist',
#   'Genpact',
#   'Gurgaon / Gurugram',
#   'Fresher',
#   'Not Specified',
#   'Job Description :\n \n With a startup spirit and 90,000+ curious and courageous minds, we have the expertise to go deep with the world\\u2019s biggest brands\\u2014and we have fun doing it. Now, we\\u2019re calling all you rule-breakers and risk-takers who',
#   'Skills: MLmodels , maintenance , StatisticalModeling , Teradata , DataScientist , PerformanceMonitoring , Hadoop , Oracle , SQLServer , MachineLearning , Sql , Python , SAS , datamining',
#   'Posted: 30+ days ago'),
#  ('Job Opportunity || Sr. Data Scientist  || 6 Months Contract–Permanent || Gurgaon',
#   'Select Source International Private Limited',
#   'Gurgaon / Gurugram',
#   '5-10 Years',
#   'Not Specified',
#   'Position: Sr. Data Scientist\n  Experience: 5–8 Yrs\n  Location: Gurgaon\n  Budget: 2LPA Per Month\n  Duration – 6 Months Contract – Permanent',
#   'Skills: "DeepLearning" , "NeuralNetworks" , "ImageProcessing" , "ComputerVision" , Cnn , Python',
#   'Posted: a month ago'),
#  None,
#  None,
#  ('Data Scientist',
#   'Speegile Consulting',
#   'Gurgaon / Gurugram, Kolkata',
#   '3-8 Years',
#   '5,00,000-8,00,000 INR',
#   'Data Scientist role with a Leading MNC in Advisory, Tax, Professional Services. Work with best people in the Consulting Industry on challenging projects on a broad range of cutting-edge data analytics and machine learning problems across industries.',
#   'Skills: Python , MachineLearning , StatisticalAnalysis',
#   'Posted: 4 days ago'),
#  ('AWS, Pyspark - Gurgaon',
#   'Magna Infotech Limited',
#   'Gurgaon / Gurugram, Noida',
#   '5-15 Years',
#   'Not Specified',
#   'Job Location: Gurgaon \n Notice period: 30days \n Experience: 5+yrs \n Role: AWS, Pyspark',
#   'Skills: "PySpark" , "PySpark" , "PythonSpark" , "PythonSpark" , "dataanalyst" , "dataengineer" , "datascience" , "dataanalytics" , "datascientist" , "AWS"',
#   'Posted: 30+ days ago'),
#  ('Job Opportunity || Sr. Data Scientist  || 6 Months Contract–Permanent',
#   'Select Source International Private Limited',
#   'Gurgaon / Gurugram',
#   '5-10 Years',
#   '12,00,000-20,00,000 INR',
#   'Position: Sr. Data Scientist\nExperience: 58 Yrs\nLocation: Gurgaon\nBudget: 2LPA Per Month\nDuration 6 Months Contract Permanent\n\nKey Skills: Deep Learning, CNN, Neural Networks, Python, Image Processing, Computer Vision\n\nEssential Duties and Responsibi',
#   'Skills: Cnn , PatternRecognition , Nlp , VideoProcessing , NeuralNetworks , MachineLearning , Python',
#   'Posted: a month ago'),
#  ('Data Scientist Senior',
#   'ANI Calls India Private Limited',
#   'Noida, India',
#   '5-8 Years',
#   '8,00,000-14,00,000 INR',
#   'Job Description :\n\n• Work comfortably with\nmulti-terabyte, and billion+ rows data to extract insights and to build\npredictive models to maximize profit\n• Utilize large-scale data mining\nand machine learning techniques to discover actionable patterns',
#   'Skills: DataScientistSenior',
#   'Posted: 19 days ago'),
#  ('Data Scientist',
#   'Globallogic Technologies Limited',
#   'Noida',
#   '3-8 Years',
#   'Not Specified',
#   'Job Description\n\n  *  Python\n\n  *  Experience of ML/DL libraries such as Tensorflow, PyTorch, XGBoost, and etc.\n\n  *  Data Scientist should have at least 3 years of experience in the ML and DL areas and at least 1 year of experience using Python and',
#   'Skills: Xgboost , Statistics , Pytorch , Tensorflow , DeepLearning , Python',
#   'Posted: 14 days ago'),
#  None,
#  None,
#  ('SAS grid consultant',
#   'ANI Calls India Private Limited',
#   'Noida, India',
#   '6-8 Years',
#   '8,00,000-16,00,000 INR',
#   'Job Description :\n\n• Develop and manage statistical programming efforts within SAS to generate the clinical datasets, tables, listings, and figures. This includes a mix of both individual hands-on SAS Programming, as well as people and process manage',
#   'Skills: SASgridconsultant',
#   'Posted: 19 days ago'),
#  ('AI / ML Data Scientist  -  Democratize commerce through Technology',
#   'CareerXperts Consulting',
#   'Noida',
#   '2-7 Years',
#   'Not Specified',
#   'AI / ML Data Scientist Democratize commerce through Technology! AI / ML Data Scientist - Democratize commerce through Technology! - CareerXperts Consulting AI / ML Data Scientist Democratize commerce through Technology!\nThe focus of our data science',
#   'Skills: ComputerScience , Analytical , Consulting , Analytics , SystemArchitecture , C++ , ImageProcessing , MachineLearning , Datamining , Python',
#   'Posted: a month ago')]

# %%
#save data in csv file
with open('monster_software_dev_jobs.csv','w', newline='',encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['postition','comapny','location','experience','salary','jd','skills','posted'])
    writer.writerows(records)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-34f2fe79a24e> in <module>
#       3     writer = csv.writer(f)
#       4     writer.writerow(['postition','comapny','location','experience','salary','jd','skills','posted'])
# ----> 5     writer.writerows(records)
#
# Error: iterable expected, not NoneType
